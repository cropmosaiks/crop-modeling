# %% [markdown]
# # Results Data Cleanup
#
# ## Setup

# %%
# %load_ext lab_black

# %%
import os
import re
import sys
import glob
import numpy as np
import pandas as pd

from pyhere import here
from scipy.stats import pearsonr
from sklearn.metrics import r2_score


sys.path.append(str(here("code", "3_task_modeling")))

import task_modeling_utils

# %%
def get_group_R2(df, observed="demean_log_yield", predicted="demean_oos_prediction"):
    return r2_score(df[observed], df[predicted])


def get_group_r2(df, observed="demean_log_yield", predicted="demean_oos_prediction"):
    return pearsonr(df[observed], df[predicted])[0]


def extract_float_from_string(s):
    if isinstance(s, str):
        match = re.search(r"\((.*),\)", s)
        return float(match.group(1)) if match else s
    else:
        return s

# %% [markdown]
# ## Global Experiment - General Model
#
# ### Model Selection

# %%
model_selection_file_pattern = str(
    here("data", "results", "2_sensor_10-splits_2023-05-*_anom-False.csv")
)
model_selection_files = glob.glob(pathname=model_selection_file_pattern)
sorted(model_selection_files)
# Out:
# ['/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-11_1_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-11_2_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-11_3_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-11_4_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-11_5_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-11_6_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-11_7_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_10_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_11_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_12_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_13_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_14_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_15_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_16_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_17_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_8_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-12_9_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-13_18_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-05-13_19_rcf_climate-False_anom-False.csv']

# %%
model_selection_results = task_modeling_utils.merge_files(model_selection_files)
model_selection_results["anomaly"] = False
model_selection_results["variables"] = "rcf"
model_selection_results
# Out:
#       split  random_state country year_range    satellite_1  \
# 0         0        670487     ZMB  2016-2021  landsat-c2-l2
# 1         1        116739     ZMB  2016-2021  landsat-c2-l2
# 2         2         26225     ZMB  2016-2021  landsat-c2-l2
# 3         3        777572     ZMB  2016-2021  landsat-c2-l2
# 4         4        288389     ZMB  2016-2021  landsat-c2-l2
# ...     ...           ...     ...        ...            ...
# 1135      5        256787     ZMB  2016-2021  landsat-c2-l2
# 1136      6        234053     ZMB  2016-2021  landsat-c2-l2
# 1137      7        146316     ZMB  2016-2021  landsat-c2-l2
# 1138      8        772246     ZMB  2016-2021  landsat-c2-l2
# 1139      9        107473     ZMB  2016-2021  landsat-c2-l2
#
#                       bands_1  num_features_1  points_1 month_range_1  \
# 0     r-g-b-nir-swir16-swir22            1024        20          1-12
# 1     r-g-b-nir-swir16-swir22            1024        20          1-12
# 2     r-g-b-nir-swir16-swir22            1024        20          1-12
# 3     r-g-b-nir-swir16-swir22            1024        20          1-12
# 4     r-g-b-nir-swir16-swir22            1024        20          1-12
# ...                       ...             ...       ...           ...
# 1135  r-g-b-nir-swir16-swir22            1024        20           4-9
# 1136  r-g-b-nir-swir16-swir22            1024        20           4-9
# 1137  r-g-b-nir-swir16-swir22            1024        20           4-9
# 1138  r-g-b-nir-swir16-swir22            1024        20           4-9
# 1139  r-g-b-nir-swir16-swir22            1024        20           4-9
#
#       limit_months_1  ...    test_r   test_r2 demean_cv_R2 demean_cv_r  \
# 0              False  ...  0.875606  0.766687     0.117839    0.519227
# 1              False  ...  0.904602  0.818305     0.132072    0.494040
# 2              False  ...  0.932698  0.869926     0.125536    0.452668
# 3              False  ...  0.913001  0.833571     0.146011    0.523675
# 4              False  ...  0.919801  0.846033    -0.002118    0.398073
# ...              ...  ...       ...       ...          ...         ...
# 1135            True  ...  0.841214  0.707641    -0.131221    0.466321
# 1136            True  ...  0.915579  0.838286     0.144304    0.480349
# 1137            True  ...  0.912913  0.833411     0.065448    0.436761
# 1138            True  ...  0.942299  0.887927     0.160958    0.485971
# 1139            True  ...  0.916873  0.840656     0.115554    0.478764
#
#       demean_cv_r2  demean_test_R2 demean_test_r  demean_test_r2  anomaly  \
# 0         0.269597        0.293401      0.561290        0.315046    False
# 1         0.244076        0.511307      0.722383        0.521837    False
# 2         0.204908        0.421614      0.668757        0.447236    False
# 3         0.274235        0.131849      0.564733        0.318923    False
# 4         0.158462        0.610579      0.784178        0.614934    False
# ...            ...             ...           ...             ...      ...
# 1135      0.217455       -0.016187      0.292059        0.085298    False
# 1136      0.230735        0.399199      0.667107        0.445031    False
# 1137      0.190760        0.366838      0.608689        0.370502    False
# 1138      0.236168        0.513391      0.718095        0.515660    False
# 1139      0.229215        0.603994      0.781375        0.610546    False
#
#       variables
# 0           rcf
# 1           rcf
# 2           rcf
# 3           rcf
# 4           rcf
# ...         ...
# 1135        rcf
# 1136        rcf
# 1137        rcf
# 1138        rcf
# 1139        rcf
#
# [1140 rows x 43 columns]

# %%
model_selection_results.val_R2.describe()
# Out:
# count    1140.000000
# mean        0.779307
# std         0.026716
# min         0.667332
# 25%         0.764163
# 50%         0.783825
# 75%         0.796886
# max         0.839085
# Name: val_R2, dtype: float64

# %%
model_selection_group_cols = [
    "variables",
    "anomaly",
    "country",
    "year_range",
    "satellite_1",
    "bands_1",
    "num_features_1",
    "points_1",
    "month_range_1",
    "limit_months_1",
    "crop_mask_1",
    "weighted_avg_1",
    "satellite_2",
    "bands_2",
    "num_features_2",
    "points_2",
    "month_range_2",
    "limit_months_2",
    "crop_mask_2",
    "weighted_avg_2",
    "hot_encode",
]

model_selection_results_summary = model_selection_results.groupby(
    model_selection_group_cols, as_index=False
).agg(
    {
        "val_R2": "mean",
        "val_r2": "mean",
        "test_R2": "mean",
        "test_r2": "mean",
    }
)
model_selection_results_summary = model_selection_results_summary.sort_values(
    "val_R2", ascending=False
)

# %% [markdown]
# ### Top Model Results

# %%
top_model = model_selection_results_summary.iloc[0:1, :]
top_model_dict = top_model.to_dict(orient="records")[0]
top_model_dict
# Out:
# {'variables': 'rcf',
#  'anomaly': False,
#  'country': 'ZMB',
#  'year_range': '2016-2021',
#  'satellite_1': 'landsat-c2-l2',
#  'bands_1': 'r-g-b-nir-swir16-swir22',
#  'num_features_1': 1024,
#  'points_1': 20,
#  'month_range_1': '4-9',
#  'limit_months_1': True,
#  'crop_mask_1': True,
#  'weighted_avg_1': False,
#  'satellite_2': 'sentinel-2-l2a',
#  'bands_2': '2-3-4-8',
#  'num_features_2': 1000,
#  'points_2': 15,
#  'month_range_2': '1-12',
#  'limit_months_2': False,
#  'crop_mask_2': True,
#  'weighted_avg_2': False,
#  'hot_encode': True,
#  'val_R2': 0.8002404610219435,
#  'val_r2': 0.8017879820931079,
#  'test_R2': 0.8258186120850981,
#  'test_r2': 0.8325650503230417}

# %%
# # Define the keys to remove
# keys_to_remove = ["val_R2", "val_r2", "test_R2", "test_r2"]

# # Remove keys
# for key in keys_to_remove:
#     if key in top_model_dict:
#         del top_model_dict[key]

# top_model_splits = model_selection_results.copy()

# for key, value in top_model_dict.items():
#     if key in model_selection_results.columns:
#         top_model_splits = top_model_splits[top_model_splits[key] == value]
# top_model_splits

# %% [markdown]
# ### Top Model Splits

# %%
top_model_file_pattern = str(
    here("data", "results", "2_sensor_top-mod_10-splits_*_*.csv")
)
top_model_files = glob.glob(pathname=top_model_file_pattern)
sorted(top_model_files)
# Out:
# ['/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-mod_10-splits_2023-07-05_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-mod_10-splits_2023-07-05_rcf_climate-True_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-mod_10-splits_2023-07-06_rcf_climate-False_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-mod_10-splits_2023-07-06_rcf_climate-True_anom-True.csv']

# %%
top_model_results = task_modeling_utils.merge_files(top_model_files)
# top_model_results["variables"] = top_model_results["variables"].apply(
#     lambda x: "rcf_" + x if "rcf" not in x else x
# )

top_model_results.head(10)
# Out:
#    split  random_state variables  anomaly country year_range    satellite_1  \
# 0      0        670487       rcf     True     ZMB  2016-2021  landsat-c2-l2
# 1      1        116739       rcf     True     ZMB  2016-2021  landsat-c2-l2
# 2      2         26225       rcf     True     ZMB  2016-2021  landsat-c2-l2
# 3      3        777572       rcf     True     ZMB  2016-2021  landsat-c2-l2
# 4      4        288389       rcf     True     ZMB  2016-2021  landsat-c2-l2
# 5      5        256787       rcf     True     ZMB  2016-2021  landsat-c2-l2
# 6      6        234053       rcf     True     ZMB  2016-2021  landsat-c2-l2
# 7      7        146316       rcf     True     ZMB  2016-2021  landsat-c2-l2
# 8      8        772246       rcf     True     ZMB  2016-2021  landsat-c2-l2
# 9      9        107473       rcf     True     ZMB  2016-2021  landsat-c2-l2
#
#                    bands_1  num_features_1  points_1  ...  train_r2   test_R2  \
# 0  r-g-b-nir-swir16-swir22            1024        20  ...  0.975638  0.454223
# 1  r-g-b-nir-swir16-swir22            1024        20  ...  0.987626  0.646691
# 2  r-g-b-nir-swir16-swir22            1024        20  ...  0.972669  0.699289
# 3  r-g-b-nir-swir16-swir22            1024        20  ...  0.997239  0.653210
# 4  r-g-b-nir-swir16-swir22            1024        20  ...  0.956340  0.529977
# 5  r-g-b-nir-swir16-swir22            1024        20  ...  0.986114  0.555285
# 6  r-g-b-nir-swir16-swir22            1024        20  ...  0.974025  0.514385
# 7  r-g-b-nir-swir16-swir22            1024        20  ...  0.988091  0.381815
# 8  r-g-b-nir-swir16-swir22            1024        20  ...  0.987443  0.688440
# 9  r-g-b-nir-swir16-swir22            1024        20  ...  0.986473  0.708049
#
#      test_r   test_r2 demean_cv_R2 demean_cv_r  demean_cv_r2  demean_test_R2  \
# 0  0.738880  0.545944          NaN         NaN           NaN             NaN
# 1  0.814142  0.662827          NaN         NaN           NaN             NaN
# 2  0.836400  0.699565          NaN         NaN           NaN             NaN
# 3  0.820834  0.673769          NaN         NaN           NaN             NaN
# 4  0.747210  0.558323          NaN         NaN           NaN             NaN
# 5  0.748132  0.559702          NaN         NaN           NaN             NaN
# 6  0.747043  0.558073          NaN         NaN           NaN             NaN
# 7  0.642125  0.412324          NaN         NaN           NaN             NaN
# 8  0.830507  0.689742          NaN         NaN           NaN             NaN
# 9  0.843981  0.712304          NaN         NaN           NaN             NaN
#
#   demean_test_r  demean_test_r2
# 0           NaN             NaN
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# 5           NaN             NaN
# 6           NaN             NaN
# 7           NaN             NaN
# 8           NaN             NaN
# 9           NaN             NaN
#
# [10 rows x 43 columns]

# %%
top_model_results.loc[
    (top_model_results["variables"] == "rcf") & (top_model_results.anomaly == False)
].iloc[:, 25:30]
# Out:
#     test_n                         best_reg_param  \
# 30      84   [[10.0, 10.0, 0.009999999999999998]]
# 31      84  [[10.0, 10.0, 0.0009999999999999998]]
# 32      84   [[100.0, 10.0, 0.09999999999999999]]
# 33      84  [[100.0, 10.0, 0.009999999999999998]]
# 34      84   [[10.0, 10.0, 0.009999999999999998]]
# 35      84  [[100.0, 10.0, 0.009999999999999998]]
# 36      84   [[10.0, 10.0, 0.009999999999999998]]
# 37      84   [[100.0, 10.0, 0.09999999999999999]]
# 38      84   [[10.0, 10.0, 0.009999999999999998]]
# 39      84  [[100.0, 10.0, 0.009999999999999998]]
#
#                                        mean_of_val_R2    val_R2     val_r
# 30  [[0.6648244030124295, 0.7101271931484556, 0.78...  0.792837  0.890883
# 31  [[0.703574744293908, 0.7455820353086114, 0.795...  0.807981  0.899629
# 32  [[0.7351356731429453, 0.7583377050863769, 0.79...  0.797153  0.893292
# 33  [[0.6880542403771379, 0.7352708239111512, 0.79...  0.796673  0.892972
# 34  [[0.7286959537558308, 0.7641489361690736, 0.82...  0.825819  0.908855
# 35  [[0.7331774863223968, 0.7559086275465114, 0.81...  0.818719  0.905189
# 36  [[0.6964254355989031, 0.7361124201081983, 0.79...  0.803079  0.896493
# 37  [[0.7355409474919525, 0.7710290473858741, 0.81...  0.813752  0.902505
# 38  [[0.724555150847279, 0.7475335680402925, 0.781...  0.783923  0.886083
# 39  [[0.6889778140977343, 0.7415109445765998, 0.78...  0.798971  0.894057

# %%
round(0.009999999999999998, 4), round(0.0009999999999, 4)
# Out:
# (0.01, 0.001)

# %%
top_model_group_cols = [
    "variables",
    "anomaly",
]

top_model_results_summary = top_model_results.groupby(
    top_model_group_cols, as_index=False
).agg(
    {
        "val_R2": "mean",
        "val_r2": "mean",
        "test_R2": "mean",
        "test_r2": "mean",
        "demean_cv_R2": "mean",
        "demean_cv_r2": "mean",
        "demean_test_R2": "mean",
        "demean_test_r2": "mean",
        # "split": "count",
    }
)
top_model_results_summary = top_model_results_summary.sort_values(
    "val_R2", ascending=False
)
top_model_results_summary
# Out:
#       variables  anomaly    val_R2    val_r2   test_R2   test_r2  \
# 4  rcf_ndvi_tmp    False  0.820895  0.821212  0.846339  0.852371
# 2      rcf_ndvi    False  0.813084  0.813852  0.837648  0.844072
# 0           rcf    False  0.803891  0.804645  0.831973  0.837512
# 5  rcf_ndvi_tmp     True  0.567000  0.590313  0.581847  0.608774
# 3      rcf_ndvi     True  0.558335  0.581892  0.585674  0.610538
# 1           rcf     True  0.537469  0.567692  0.583136  0.607257
#
#    demean_cv_R2  demean_cv_r2  demean_test_R2  demean_test_r2
# 4      0.249587      0.303363        0.465455        0.489834
# 2      0.211704      0.265298        0.449108        0.478338
# 0      0.172972      0.233819        0.422436        0.452334
# 5           NaN           NaN             NaN             NaN
# 3           NaN           NaN             NaN             NaN
# 1           NaN           NaN             NaN             NaN

# %%
top_model_group_cols = [
    "variables",
    "anomaly",
]

top_model_results_summary = top_model_results.groupby(
    top_model_group_cols, as_index=False
).agg(
    {
        "val_R2": "sem",
        "val_r2": "sem",
        "test_R2": "sem",
        "test_r2": "sem",
        "split": "count",
    }
)
top_model_results_summary = top_model_results_summary.sort_values(
    "val_R2", ascending=False
)
top_model_results_summary
# Out:
#       variables  anomaly    val_R2    val_r2   test_R2   test_r2  split
# 5  rcf_ndvi_tmp     True  0.012316  0.009095  0.041445  0.035144     10
# 3      rcf_ndvi     True  0.012280  0.008519  0.043679  0.037243     10
# 1           rcf     True  0.011523  0.008428  0.035685  0.030314     10
# 4  rcf_ndvi_tmp    False  0.004607  0.004645  0.010258  0.010288     10
# 0           rcf    False  0.004025  0.003972  0.010714  0.010837     10
# 2      rcf_ndvi    False  0.003810  0.003715  0.010226  0.010330     10

# %% [markdown]
# ### Out of Sample Predictions

# %%
oos_prediction_file_pattern = str(
    here(
        "data", "results", "2_sensor_top-mod_oos_predictions_10-splits_*_anom-False.csv"
    )
)
oos_prediction_files = glob.glob(pathname=oos_prediction_file_pattern)
sorted(oos_prediction_files)
# Out:
# ['/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-mod_oos_predictions_10-splits_2023-07-05_rcf_climate-True_anom-False.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-mod_oos_predictions_10-splits_2023-07-06_rcf_climate-False_anom-False.csv']

# %%
oos_prediction = task_modeling_utils.merge_files(oos_prediction_files)
# oos_prediction

# %%
oos_prediction_demean_groups = [
    # "data_fold",
    "district",
    # "val_fold",
    "split",
    "random_state",
    "variables",
]
oos_prediction = task_modeling_utils.demean_by_group(
    df=oos_prediction,
    observed="log_yield",
    predicted="oos_prediction",
    group=oos_prediction_demean_groups,
)
oos_prediction
# Out:
#       data_fold    district  year  yield_mt  log_yield  demean_log_yield  \
# 0         train       Kaoma  2019  0.523864   0.182946         -0.192782
# 1         train       Kaoma  2017  1.540420   0.404906          0.029177
# 2         train  Sinazongwe  2020  0.589120   0.201157         -0.021142
# 3         train     Kasempa  2020  3.349064   0.638396          0.077697
# 4         train   Shangombo  2020  0.741213   0.240852          0.071072
# ...         ...         ...   ...       ...        ...               ...
# 12595      test     Chadiza  2018  1.299279   0.361592         -0.142270
# 12596      test      Mkushi  2020  2.819023   0.581952         -0.022751
# 12597      test       Kitwe  2020  2.771743   0.576542          0.027490
# 12598      test   Nchelenge  2019  1.604964   0.415802         -0.090286
# 12599      test     Chavuma  2019  1.287703   0.359400         -0.156889
#
#        oos_prediction  val_fold  split  random_state variables  anomaly  \
# 0            0.279597         1      0        670487  rcf_ndvi    False
# 1            0.368818         1      0        670487  rcf_ndvi    False
# 2            0.205443         1      0        670487  rcf_ndvi    False
# 3            0.556458         1      0        670487  rcf_ndvi    False
# 4            0.167303         1      0        670487  rcf_ndvi    False
# ...               ...       ...    ...           ...       ...      ...
# 12595        0.514470         6      9        107473       rcf    False
# 12596        0.605807         6      9        107473       rcf    False
# 12597        0.562126         6      9        107473       rcf    False
# 12598        0.512967         6      9        107473       rcf    False
# 12599        0.500988         6      9        107473       rcf    False
#
#        hot_encode  demean_oos_prediction
# 0            True              -0.083021
# 1            True               0.006200
# 2            True              -0.040686
# 3            True               0.005091
# 4            True              -0.025521
# ...           ...                    ...
# 12595        True              -0.009694
# 12596        True              -0.004002
# 12597        True               0.020002
# 12598        True              -0.024283
# 12599        True              -0.042586
#
# [12600 rows x 14 columns]

# %%
oos_prediction_r2_groups = [
    "data_fold",
    "split",
    "random_state",
    "variables",
]

oos_prediction_R2 = oos_prediction.groupby(
    oos_prediction_r2_groups, as_index=False
).apply(get_group_R2)
oos_prediction_R2.rename(columns={None: "demean_R2"}, inplace=True)

oos_prediction_r2 = oos_prediction.groupby(
    oos_prediction_r2_groups, as_index=False
).apply(get_group_r2)
oos_prediction_r2.rename(columns={None: "demean_r"}, inplace=True)

oos_prediction_r2["demean_r2"] = oos_prediction_r2["demean_r"] ** 2

oos_prediction_summary = (
    oos_prediction_R2.set_index(oos_prediction_r2_groups)
    .join(oos_prediction_r2.set_index(oos_prediction_r2_groups))
    .reset_index()
)

oos_prediction_summary.sort_values(["variables", "data_fold"])
# Out:
#    data_fold  split  random_state     variables  demean_R2  demean_r  \
# 0       test      0        670487           rcf   0.493625  0.714968
# 3       test      1        116739           rcf   0.543294  0.743477
# 6       test      2         26225           rcf   0.512101  0.716613
# 9       test      3        777572           rcf   0.356677  0.612213
# 12      test      4        288389           rcf   0.311237  0.634666
# 15      test      5        256787           rcf   0.429404  0.660930
# 18      test      6        234053           rcf   0.311245  0.610583
# 21      test      7        146316           rcf   0.207081  0.522681
# 24      test      8        772246           rcf   0.576371  0.762522
# 27      test      9        107473           rcf   0.483330  0.709921
# 30     train      0        670487           rcf   0.145977  0.465203
# 33     train      1        116739           rcf   0.139248  0.472333
# 36     train      2         26225           rcf   0.113019  0.436363
# 39     train      3        777572           rcf   0.175402  0.479882
# 42     train      4        288389           rcf   0.251152  0.540365
# 45     train      5        256787           rcf   0.183067  0.477752
# 48     train      6        234053           rcf   0.224280  0.526839
# 51     train      7        146316           rcf   0.236801  0.525446
# 54     train      8        772246           rcf   0.131463  0.461626
# 57     train      9        107473           rcf   0.129309  0.437016
# 1       test      0        670487      rcf_ndvi   0.555521  0.750058
# 4       test      1        116739      rcf_ndvi   0.551179  0.748944
# 7       test      2         26225      rcf_ndvi   0.563886  0.753789
# 10      test      3        777572      rcf_ndvi   0.410599  0.653944
# 13      test      4        288389      rcf_ndvi   0.314640  0.638554
# 16      test      5        256787      rcf_ndvi   0.438918  0.668608
# 19      test      6        234053      rcf_ndvi   0.317910  0.618274
# 22      test      7        146316      rcf_ndvi   0.217046  0.536315
# 25      test      8        772246      rcf_ndvi   0.596584  0.775945
# 28      test      9        107473      rcf_ndvi   0.524799  0.732981
# 31     train      0        670487      rcf_ndvi   0.199533  0.521960
# 34     train      1        116739      rcf_ndvi   0.146753  0.477639
# 37     train      2         26225      rcf_ndvi   0.161093  0.473315
# 40     train      3        777572      rcf_ndvi   0.228230  0.524635
# 43     train      4        288389      rcf_ndvi   0.303840  0.576681
# 46     train      5        256787      rcf_ndvi   0.197157  0.487964
# 49     train      6        234053      rcf_ndvi   0.272586  0.559670
# 52     train      7        146316      rcf_ndvi   0.270622  0.553240
# 55     train      8        772246      rcf_ndvi   0.163320  0.486983
# 58     train      9        107473      rcf_ndvi   0.173910  0.475395
# 2       test      0        670487  rcf_ndvi_tmp   0.568540  0.757650
# 5       test      1        116739  rcf_ndvi_tmp   0.573907  0.758988
# 8       test      2         26225  rcf_ndvi_tmp   0.573961  0.757984
# 11      test      3        777572  rcf_ndvi_tmp   0.383823  0.649646
# 14      test      4        288389  rcf_ndvi_tmp   0.339076  0.649819
# 17      test      5        256787  rcf_ndvi_tmp   0.439196  0.664096
# 20      test      6        234053  rcf_ndvi_tmp   0.358652  0.651360
# 23      test      7        146316  rcf_ndvi_tmp   0.279227  0.557542
# 26      test      8        772246  rcf_ndvi_tmp   0.622433  0.790368
# 29      test      9        107473  rcf_ndvi_tmp   0.515733  0.727031
# 32     train      0        670487  rcf_ndvi_tmp   0.210600  0.523409
# 35     train      1        116739  rcf_ndvi_tmp   0.206086  0.523945
# 38     train      2         26225  rcf_ndvi_tmp   0.187512  0.499284
# 41     train      3        777572  rcf_ndvi_tmp   0.266727  0.559646
# 44     train      4        288389  rcf_ndvi_tmp   0.340967  0.610361
# 47     train      5        256787  rcf_ndvi_tmp   0.276380  0.559635
# 50     train      6        234053  rcf_ndvi_tmp   0.316492  0.607350
# 53     train      7        146316  rcf_ndvi_tmp   0.281180  0.563534
# 56     train      8        772246  rcf_ndvi_tmp   0.197336  0.520603
# 59     train      9        107473  rcf_ndvi_tmp   0.212591  0.528644
#
#     demean_r2
# 0    0.511180
# 3    0.552759
# 6    0.513534
# 9    0.374805
# 12   0.402801
# 15   0.436828
# 18   0.372811
# 21   0.273196
# 24   0.581439
# 27   0.503988
# 30   0.216414
# 33   0.223098
# 36   0.190412
# 39   0.230287
# 42   0.291994
# 45   0.228247
# 48   0.277559
# 51   0.276094
# 54   0.213098
# 57   0.190983
# 1    0.562588
# 4    0.560917
# 7    0.568198
# 10   0.427643
# 13   0.407752
# 16   0.447036
# 19   0.382262
# 22   0.287633
# 25   0.602090
# 28   0.537261
# 31   0.272442
# 34   0.228139
# 37   0.224027
# 40   0.275242
# 43   0.332561
# 46   0.238109
# 49   0.313231
# 52   0.306075
# 55   0.237152
# 58   0.226000
# 2    0.574034
# 5    0.576062
# 8    0.574539
# 11   0.422040
# 14   0.422264
# 17   0.441023
# 20   0.424270
# 23   0.310854
# 26   0.624682
# 29   0.528574
# 32   0.273957
# 35   0.274518
# 38   0.249285
# 41   0.313204
# 44   0.372540
# 47   0.313192
# 50   0.368874
# 53   0.317571
# 56   0.271028
# 59   0.279465

# %%
oos_prediction_summary_r2_groups = [
    "data_fold",
    "variables",
]
oos_prediction_summary = (
    oos_prediction_summary.groupby(oos_prediction_summary_r2_groups, as_index=False)
    .agg(
        {
            "demean_R2": "mean",
            "demean_r2": "mean",
            "demean_R2": "sem",
            "demean_r2": "sem",
        }
    )
    .sort_values("variables")
)
oos_prediction_summary
# Out:
#   data_fold     variables  demean_R2  demean_r2
# 0      test           rcf   0.038093   0.030505
# 3     train           rcf   0.015641   0.011399
# 1      test      rcf_ndvi   0.041248   0.032474
# 4     train      rcf_ndvi   0.017272   0.012821
# 2      test  rcf_ndvi_tmp   0.038115   0.031493
# 5     train  rcf_ndvi_tmp   0.017062   0.013212

# %%
# Pivot the DataFrame
oos_prediction_summary = oos_prediction_summary.pivot_table(
    index="variables", columns="data_fold"
)

# Flatten the MultiIndex columns
oos_prediction_summary.columns = [
    "_".join(col) for col in oos_prediction_summary.columns
]

# Reset the index
oos_prediction_summary = oos_prediction_summary.reset_index()
oos_prediction_summary = oos_prediction_summary.set_index(
    [
        "variables",
        "demean_R2_train",
        "demean_r2_train",
        "demean_R2_test",
        "demean_r2_test",
    ]
)
oos_prediction_summary = oos_prediction_summary.reset_index()
oos_prediction_summary.sort_values("demean_R2_train", ascending=False)
# Out:
#       variables  demean_R2_train  demean_r2_train  demean_R2_test  \
# 1      rcf_ndvi         0.017272         0.012821        0.041248
# 2  rcf_ndvi_tmp         0.017062         0.013212        0.038115
# 0           rcf         0.015641         0.011399        0.038093
#
#    demean_r2_test
# 1        0.032474
# 2        0.031493
# 0        0.030505

# %% [markdown]
# ### Anomaly Model

# %%
anomaly_file_pattern = str(
    here(
        "data", "results", "2_sensor_top-mod_oos_predictions_10-splits_*_anom-True.csv"
    )
)
anomaly_files = glob.glob(pathname=anomaly_file_pattern)
sorted(anomaly_files)
# Out:
# ['/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-mod_oos_predictions_10-splits_2023-07-05_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-mod_oos_predictions_10-splits_2023-07-06_rcf_climate-True_anom-True.csv']

# %%
anomaly_predictions = task_modeling_utils.merge_files(anomaly_files)
anomaly_predictions
# Out:
#       data_fold    district  year  yield_mt  log_yield  demean_log_yield  \
# 0         train       Kaoma  2019 -0.898481  -0.192782         -0.192782
# 1         train       Kaoma  2017  0.118076   0.029177          0.029177
# 2         train  Sinazongwe  2020 -0.125243  -0.021142         -0.021142
# 3         train     Kasempa  2020  0.694315   0.077697          0.077697
# 4         train   Shangombo  2020  0.239461   0.071072          0.071072
# ...         ...         ...   ...       ...        ...               ...
# 12595      test     Chadiza  2018 -0.939644  -0.142270         -0.142270
# 12596      test      Mkushi  2020 -0.230178  -0.022751         -0.022751
# 12597      test       Kitwe  2020  0.216271   0.027490          0.027490
# 12598      test   Nchelenge  2019 -0.618532  -0.090286         -0.090286
# 12599      test     Chavuma  2019 -1.060647  -0.156889         -0.156889
#
#        oos_prediction  val_fold  split  random_state     variables  anomaly  \
# 0           -0.056889         1      0        670487           rcf     True
# 1            0.017457         1      0        670487           rcf     True
# 2           -0.031136         1      0        670487           rcf     True
# 3            0.072680         1      0        670487           rcf     True
# 4            0.046946         1      0        670487           rcf     True
# ...               ...       ...    ...           ...           ...      ...
# 12595       -0.065308         6      9        107473  rcf_ndvi_tmp     True
# 12596        0.000990         6      9        107473  rcf_ndvi_tmp     True
# 12597        0.067018         6      9        107473  rcf_ndvi_tmp     True
# 12598        0.009173         6      9        107473  rcf_ndvi_tmp     True
# 12599       -0.073778         6      9        107473  rcf_ndvi_tmp     True
#
#        hot_encode  demean_oos_prediction
# 0            True              -0.067769
# 1            True               0.006577
# 2            True              -0.022356
# 3            True               0.070367
# 4            True               0.052757
# ...           ...                    ...
# 12595        True              -0.070035
# 12596        True               0.008657
# 12597        True               0.056572
# 12598        True               0.018344
# 12599        True              -0.052181
#
# [12600 rows x 14 columns]

# %%
r2_groups = [
    "data_fold",
    "split",
    "random_state",
    "variables",
]

grouped_R2 = anomaly_predictions.groupby(r2_groups, as_index=False).apply(
    get_group_R2, "log_yield", "oos_prediction"
)
grouped_R2.rename(columns={None: "demean_R2"}, inplace=True)

grouped_r2 = anomaly_predictions.groupby(r2_groups, as_index=False).apply(
    get_group_r2, "log_yield", "oos_prediction"
)
grouped_r2.rename(columns={None: "demean_r"}, inplace=True)

grouped_r2["demean_r2"] = oos_prediction_r2["demean_r"] ** 2

oos_prediction_summary = (
    grouped_R2.set_index(r2_groups).join(grouped_r2.set_index(r2_groups)).reset_index()
)

# oos_prediction_summary.sort_values(["variables", "data_fold"])
# Out:
#    data_fold  split  random_state     variables  demean_R2  demean_r  \
# 0       test      0        670487           rcf   0.454223  0.738880
# 3       test      1        116739           rcf   0.646691  0.814142
# 6       test      2         26225           rcf   0.699289  0.836400
# 9       test      3        777572           rcf   0.653210  0.820834
# 12      test      4        288389           rcf   0.529977  0.747210
# 15      test      5        256787           rcf   0.555285  0.748132
# 18      test      6        234053           rcf   0.514385  0.747043
# 21      test      7        146316           rcf   0.381815  0.642125
# 24      test      8        772246           rcf   0.688440  0.830507
# 27      test      9        107473           rcf   0.708049  0.843981
# 30     train      0        670487           rcf   0.614156  0.792166
# 33     train      1        116739           rcf   0.543044  0.749600
# 36     train      2         26225           rcf   0.520626  0.737535
# 39     train      3        777572           rcf   0.488874  0.739400
# 42     train      4        288389           rcf   0.570178  0.766840
# 45     train      5        256787           rcf   0.521787  0.752156
# 48     train      6        234053           rcf   0.557573  0.764316
# 51     train      7        146316           rcf   0.517569  0.735585
# 54     train      8        772246           rcf   0.539115  0.754623
# 57     train      9        107473           rcf   0.501772  0.740484
# 1       test      0        670487      rcf_ndvi   0.466224  0.743608
# 4       test      1        116739      rcf_ndvi   0.681725  0.833453
# 7       test      2         26225      rcf_ndvi   0.709643  0.842478
# 10      test      3        777572      rcf_ndvi   0.650490  0.822249
# 13      test      4        288389      rcf_ndvi   0.556075  0.759584
# 16      test      5        256787      rcf_ndvi   0.571911  0.756755
# 19      test      6        234053      rcf_ndvi   0.422852  0.686772
# 22      test      7        146316      rcf_ndvi   0.340638  0.623488
# 25      test      8        772246      rcf_ndvi   0.719230  0.848257
# 28      test      9        107473      rcf_ndvi   0.737947  0.861595
# 31     train      0        670487      rcf_ndvi   0.616993  0.793801
# 34     train      1        116739      rcf_ndvi   0.561302  0.760099
# 37     train      2         26225      rcf_ndvi   0.521663  0.738246
# 40     train      3        777572      rcf_ndvi   0.501391  0.744218
# 43     train      4        288389      rcf_ndvi   0.589793  0.777924
# 46     train      5        256787      rcf_ndvi   0.579987  0.771700
# 49     train      6        234053      rcf_ndvi   0.599809  0.777786
# 52     train      7        146316      rcf_ndvi   0.552339  0.757381
# 55     train      8        772246      rcf_ndvi   0.548993  0.759861
# 58     train      9        107473      rcf_ndvi   0.511074  0.745341
# 2       test      0        670487  rcf_ndvi_tmp   0.446707  0.734050
# 5       test      1        116739  rcf_ndvi_tmp   0.691979  0.838068
# 8       test      2         26225  rcf_ndvi_tmp   0.706645  0.840708
# 11      test      3        777572  rcf_ndvi_tmp   0.606688  0.808741
# 14      test      4        288389  rcf_ndvi_tmp   0.569252  0.765050
# 17      test      5        256787  rcf_ndvi_tmp   0.544487  0.741206
# 20      test      6        234053  rcf_ndvi_tmp   0.426113  0.694338
# 23      test      7        146316  rcf_ndvi_tmp   0.377921  0.643899
# 26      test      8        772246  rcf_ndvi_tmp   0.725886  0.852052
# 29      test      9        107473  rcf_ndvi_tmp   0.722796  0.853408
# 32     train      0        670487  rcf_ndvi_tmp   0.625439  0.799048
# 35     train      1        116739  rcf_ndvi_tmp   0.566697  0.762618
# 38     train      2         26225  rcf_ndvi_tmp   0.522314  0.738633
# 41     train      3        777572  rcf_ndvi_tmp   0.520864  0.754711
# 44     train      4        288389  rcf_ndvi_tmp   0.597871  0.782617
# 47     train      5        256787  rcf_ndvi_tmp   0.595961  0.783266
# 50     train      6        234053  rcf_ndvi_tmp   0.611830  0.786276
# 53     train      7        146316  rcf_ndvi_tmp   0.555258  0.759403
# 56     train      8        772246  rcf_ndvi_tmp   0.550238  0.760800
# 59     train      9        107473  rcf_ndvi_tmp   0.523531  0.753765
#
#     demean_r2
# 0    0.511180
# 3    0.552759
# 6    0.513534
# 9    0.374805
# 12   0.402801
# 15   0.436828
# 18   0.372811
# 21   0.273196
# 24   0.581439
# 27   0.503988
# 30   0.216414
# 33   0.223098
# 36   0.190412
# 39   0.230287
# 42   0.291994
# 45   0.228247
# 48   0.277559
# 51   0.276094
# 54   0.213098
# 57   0.190983
# 1    0.562588
# 4    0.560917
# 7    0.568198
# 10   0.427643
# 13   0.407752
# 16   0.447036
# 19   0.382262
# 22   0.287633
# 25   0.602090
# 28   0.537261
# 31   0.272442
# 34   0.228139
# 37   0.224027
# 40   0.275242
# 43   0.332561
# 46   0.238109
# 49   0.313231
# 52   0.306075
# 55   0.237152
# 58   0.226000
# 2    0.574034
# 5    0.576062
# 8    0.574539
# 11   0.422040
# 14   0.422264
# 17   0.441023
# 20   0.424270
# 23   0.310854
# 26   0.624682
# 29   0.528574
# 32   0.273957
# 35   0.274518
# 38   0.249285
# 41   0.313204
# 44   0.372540
# 47   0.313192
# 50   0.368874
# 53   0.317571
# 56   0.271028
# 59   0.279465

# %%
demean_summary_r2_groups = [
    "data_fold",
    "variables",
]
oos_prediction_summary.groupby(demean_summary_r2_groups, as_index=False).agg(
    {
        "demean_R2": "mean",
        "demean_r2": "mean",
    }
).sort_values("variables")
# Out:
#   data_fold     variables  demean_R2  demean_r2
# 0      test           rcf   0.583136   0.452334
# 3     train           rcf   0.537469   0.233819
# 1      test      rcf_ndvi   0.585674   0.478338
# 4     train      rcf_ndvi   0.558335   0.265298
# 2      test  rcf_ndvi_tmp   0.581847   0.489834
# 5     train  rcf_ndvi_tmp   0.567000   0.303363

# %% [markdown]
# ## Anomaly Model
#
# ### Model Selection

# %%
model_selection_file_pattern = str(
    here("data", "results", "2_sensor_10-splits_*_anom-True.csv")
)
model_selection_files = glob.glob(pathname=model_selection_file_pattern)
sorted(model_selection_files)
# Out:
# ['/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-28_1_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-28_2_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-28_3_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-28_4_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-28_5_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-28_6_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-29_10_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-29_11_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-29_12_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-29_7_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-29_8_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-29_9_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-30_13_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-30_14_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_10-splits_2023-06-30_15_rcf_climate-False_anom-True.csv']

# %%
model_selection_results = task_modeling_utils.merge_files(model_selection_files)
model_selection_results = model_selection_results.dropna(axis=1, how="all")
model_selection_results
# Out:
#      split  random_state variables  anomaly country year_range  \
# 0        0        670487       rcf     True     ZMB  2014-2021
# 1        1        116739       rcf     True     ZMB  2014-2021
# 2        2         26225       rcf     True     ZMB  2014-2021
# 3        3        777572       rcf     True     ZMB  2014-2021
# 4        4        288389       rcf     True     ZMB  2014-2021
# ..     ...           ...       ...      ...     ...        ...
# 895      5        256787       rcf     True     ZMB  2016-2022
# 896      6        234053       rcf     True     ZMB  2016-2022
# 897      7        146316       rcf     True     ZMB  2016-2022
# 898      8        772246       rcf     True     ZMB  2016-2022
# 899      9        107473       rcf     True     ZMB  2016-2022
#
#          satellite_1        bands_1  num_features_1  points_1  ...  \
# 0    landsat-8-c2-l2  1-2-3-4-5-6-7            1000        15  ...
# 1    landsat-8-c2-l2  1-2-3-4-5-6-7            1000        15  ...
# 2    landsat-8-c2-l2  1-2-3-4-5-6-7            1000        15  ...
# 3    landsat-8-c2-l2  1-2-3-4-5-6-7            1000        15  ...
# 4    landsat-8-c2-l2  1-2-3-4-5-6-7            1000        15  ...
# ..               ...            ...             ...       ...  ...
# 895   sentinel-2-l2a          2-3-4            1000         4  ...
# 896   sentinel-2-l2a          2-3-4            1000         4  ...
# 897   sentinel-2-l2a          2-3-4            1000         4  ...
# 898   sentinel-2-l2a          2-3-4            1000         4  ...
# 899   sentinel-2-l2a          2-3-4            1000         4  ...
#
#                                    mean_of_val_R2    val_R2     val_r  \
# 0    [[0.20962120884393354, 0.32375418573679704]]  0.350928  0.615195
# 1    [[0.14964826236827716, 0.28861209159165735]]  0.341339  0.610577
# 2     [[0.1642373513973112, 0.19659132452419187]]  0.228736  0.533863
# 3     [[0.28997967568245275, 0.3625419520053873]]  0.380669  0.621001
# 4      [[0.3376818293112775, 0.4178160858272063]]  0.454525  0.680078
# ..                                            ...       ...       ...
# 895    [[0.2663388308746587, 0.4101177035726672]]  0.405602  0.642290
# 896    [[0.4313176357145322, 0.4613189019065264]]  0.473084  0.687932
# 897    [[0.3888074388033191, 0.4495030964331378]]  0.457212  0.676577
# 898    [[0.3775894990531866, 0.4570836198289194]]  0.468138  0.685936
# 899   [[0.2844271974742112, 0.35367458828369597]]  0.384153  0.628465
#
#        val_r2  train_R2   train_r  train_r2   test_R2    test_r   test_r2
# 0    0.378465  0.916672  0.964241  0.929761  0.314842  0.582788  0.339641
# 1    0.372804  0.915503  0.963208  0.927770  0.281188  0.609699  0.371733
# 2    0.285010  0.937866  0.974249  0.949161  0.556001  0.771852  0.595755
# 3    0.385642  0.804948  0.914029  0.835449  0.309338  0.560592  0.314263
# 4    0.462506  0.943372  0.976125  0.952821  0.177294  0.589068  0.347001
# ..        ...       ...       ...       ...       ...       ...       ...
# 895  0.412536  0.740603  0.871393  0.759326  0.431489  0.661219  0.437210
# 896  0.473250  0.792304  0.901272  0.812291  0.453518  0.679583  0.461833
# 897  0.457756  0.763701  0.886123  0.785213  0.401973  0.655530  0.429719
# 898  0.470508  0.744719  0.874096  0.764044  0.370545  0.612061  0.374618
# 899  0.394968  0.732253  0.868059  0.753527  0.528610  0.727764  0.529641
#
# [900 rows x 37 columns]

# %%
model_selection_group_cols = [
    "variables",
    "anomaly",
    "country",
    "year_range",
    "satellite_1",
    "bands_1",
    "num_features_1",
    "points_1",
    "month_range_1",
    "limit_months_1",
    "crop_mask_1",
    "weighted_avg_1",
    "satellite_2",
    "bands_2",
    "num_features_2",
    "points_2",
    "month_range_2",
    "limit_months_2",
    "crop_mask_2",
    "weighted_avg_2",
]

model_selection_results_summary = model_selection_results.groupby(
    model_selection_group_cols, as_index=False
).agg(
    {
        "val_R2": "mean",
        "val_r2": "mean",
        "test_R2": "mean",
        "test_r2": "mean",
    }
)
model_selection_results_summary = model_selection_results_summary.sort_values(
    "val_R2", ascending=False
)
model_selection_results_summary
# Out:
#    variables  anomaly country year_range      satellite_1  \
# 14       rcf     True     ZMB  2016-2021  landsat-8-c2-l2
# 46       rcf     True     ZMB  2016-2021    landsat-c2-l2
# 30       rcf     True     ZMB  2016-2021  landsat-8-c2-l2
# 54       rcf     True     ZMB  2016-2021    landsat-c2-l2
# 38       rcf     True     ZMB  2016-2021  landsat-8-c2-l2
# ..       ...      ...     ...        ...              ...
# 69       rcf     True     ZMB  2016-2022   sentinel-2-l2a
# 10       rcf     True     ZMB  2014-2021  landsat-8-c2-l2
# 5        rcf     True     ZMB  2014-2021  landsat-8-c2-l2
# 13       rcf     True     ZMB  2014-2021  landsat-8-c2-l2
# 76       rcf     True     ZMB  2016-2022   sentinel-2-l2a
#
#                     bands_1  num_features_1  points_1 month_range_1  \
# 14            1-2-3-4-5-6-7            1000        15          1-12
# 46  r-g-b-nir-swir16-swir22            1024        20          1-12
# 30            1-2-3-4-5-6-7            1000        20          1-12
# 54  r-g-b-nir-swir16-swir22            1024        20           4-9
# 38            1-2-3-4-5-6-7            1000        20           4-9
# ..                      ...             ...       ...           ...
# 69                    2-3-4            1000        15           4-9
# 10            1-2-3-4-5-6-7            1000        15           4-9
# 5             1-2-3-4-5-6-7            1000        15          1-12
# 13            1-2-3-4-5-6-7            1000        20           4-9
# 76                    2-3-4            1000        20           4-9
#
#     limit_months_1  ...  num_features_2  points_2 month_range_2  \
# 14           False  ...            1000         4          1-12
# 46           False  ...            1000         4          1-12
# 30           False  ...            1000         4          1-12
# 54            True  ...            1000         4          1-12
# 38            True  ...            1000         4          1-12
# ..             ...  ...             ...       ...           ...
# 69            True  ...            1000         4           4-9
# 10            True  ...            1000        20          1-12
# 5            False  ...            1000        20          1-12
# 13            True  ...            1000        20          1-12
# 76            True  ...            1000         4           4-9
#
#    limit_months_2  crop_mask_2  weighted_avg_2    val_R2    val_r2   test_R2  \
# 14          False         True           False  0.625838  0.634117  0.694785
# 46          False         True           False  0.587637  0.601613  0.599024
# 30          False         True           False  0.577214  0.591571  0.573207
# 54          False         True           False  0.575845  0.579485  0.576837
# 38          False         True           False  0.573925  0.580842  0.536521
# ..            ...          ...             ...       ...       ...       ...
# 69           True         True           False  0.322453  0.351643  0.204375
# 10          False         True           False  0.307883  0.354537  0.349738
# 5           False         True           False  0.294726  0.353522  0.140393
# 13          False         True           False  0.280281  0.297467  0.080351
# 76           True         True           False  0.276016  0.282661  0.224165
#
#      test_r2
# 14  0.720626
# 46  0.632362
# 30  0.657712
# 54  0.593267
# 38  0.584403
# ..       ...
# 69  0.333220
# 10  0.425035
# 5   0.303955
# 13  0.224114
# 76  0.279436
#
# [90 rows x 24 columns]

# %%
top_model = model_selection_results_summary.iloc[0:1, :]
top_model_dict = top_model.to_dict(orient="records")[0]
top_model_dict
# Out:
# {'variables': 'rcf',
#  'anomaly': True,
#  'country': 'ZMB',
#  'year_range': '2016-2021',
#  'satellite_1': 'landsat-8-c2-l2',
#  'bands_1': '1-2-3-4-5-6-7',
#  'num_features_1': 1000,
#  'points_1': 15,
#  'month_range_1': '1-12',
#  'limit_months_1': False,
#  'crop_mask_1': True,
#  'weighted_avg_1': False,
#  'satellite_2': 'sentinel-2-l2a',
#  'bands_2': '2-3-4',
#  'num_features_2': 1000,
#  'points_2': 4,
#  'month_range_2': '1-12',
#  'limit_months_2': False,
#  'crop_mask_2': True,
#  'weighted_avg_2': False,
#  'val_R2': 0.6258380146218993,
#  'val_r2': 0.6341167754625727,
#  'test_R2': 0.694785309391216,
#  'test_r2': 0.7206264487364556}

# %%
f1 = "landsat-8-c2-l2_bands-1-2-3-4-5-6-7_ZMB_15k-points_1000-features_yr-2014-2021_mn-1-12_lm-False_cm-True_wa-False_summary.feather"
f2 = "sentinel-2-l2a_bands-2-3-4_ZMB_4k-points_1000-features_yr-2016-2022_mn-1-12_lm-False_cm-True_wa-False_summary.feather"

# %% [markdown]
# ### Top Over Time Model Splits

# %%
top_ot_model_file_pattern = str(
    here("data", "results", "2_sensor_top-ot-mod_10-splits_*_*.csv")
)
top_ot_model_files = glob.glob(pathname=top_ot_model_file_pattern)
sorted(top_ot_model_files)
# Out:
# ['/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-ot-mod_10-splits_2023-06-30_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-ot-mod_10-splits_2023-06-30_rcf_climate-True_anom-True.csv']

# %%
top_ot_model_results = task_modeling_utils.merge_files(top_ot_model_files)

top_ot_model_results["variables"] = top_ot_model_results["variables"].apply(
    lambda x: "rcf_" + x if "rcf" not in x else x
)
top_ot_model_results.head(10)
# Out:
#    split  random_state variables  anomaly country year_range      satellite_1  \
# 0      0        670487  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
# 1      1        116739  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
# 2      2         26225  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
# 3      3        777572  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
# 4      4        288389  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
# 5      5        256787  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
# 6      6        234053  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
# 7      7        146316  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
# 8      8        772246  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
# 9      9        107473  rcf_ndvi     True     ZMB  2016-2021  landsat-8-c2-l2
#
#          bands_1  num_features_1  points_1  ...  train_r2   test_R2    test_r  \
# 0  1-2-3-4-5-6-7            1000        15  ...  0.996305  0.389761  0.737305
# 1  1-2-3-4-5-6-7            1000        15  ...  0.995800  0.696153  0.835465
# 2  1-2-3-4-5-6-7            1000        15  ...  0.991247  0.590510  0.801708
# 3  1-2-3-4-5-6-7            1000        15  ...  0.993892  0.819431  0.905369
# 4  1-2-3-4-5-6-7            1000        15  ...  0.995050  0.755194  0.870068
# 5  1-2-3-4-5-6-7            1000        15  ...  0.995116  0.756721  0.873003
# 6  1-2-3-4-5-6-7            1000        15  ...  0.995074  0.748927  0.885858
# 7  1-2-3-4-5-6-7            1000        15  ...  0.995734  0.688746  0.835809
# 8  1-2-3-4-5-6-7            1000        15  ...  0.999204  0.701865  0.840842
# 9  1-2-3-4-5-6-7            1000        15  ...  0.998995  0.841393  0.918779
#
#     test_r2 demean_cv_R2 demean_cv_r  demean_cv_r2  demean_test_R2  \
# 0  0.543618          NaN         NaN           NaN             NaN
# 1  0.698001          NaN         NaN           NaN             NaN
# 2  0.642736          NaN         NaN           NaN             NaN
# 3  0.819694          NaN         NaN           NaN             NaN
# 4  0.757018          NaN         NaN           NaN             NaN
# 5  0.762134          NaN         NaN           NaN             NaN
# 6  0.784745          NaN         NaN           NaN             NaN
# 7  0.698576          NaN         NaN           NaN             NaN
# 8  0.707015          NaN         NaN           NaN             NaN
# 9  0.844155          NaN         NaN           NaN             NaN
#
#   demean_test_r  demean_test_r2
# 0           NaN             NaN
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# 5           NaN             NaN
# 6           NaN             NaN
# 7           NaN             NaN
# 8           NaN             NaN
# 9           NaN             NaN
#
# [10 rows x 43 columns]

# %%
top_model_group_cols = [
    "variables",
    "anomaly",
]

top_ot_model_results_summary = top_ot_model_results.groupby(
    top_model_group_cols, as_index=False
).agg(
    {
        "val_R2": "mean",
        "val_r2": "mean",
        "test_R2": "mean",
        "test_r2": "mean",
        "demean_cv_R2": "mean",
        "demean_cv_r2": "mean",
        "demean_test_R2": "mean",
        "demean_test_r2": "mean",
        # "split": "count",
    }
)
top_ot_model_results_summary = top_ot_model_results_summary.sort_values(
    "val_R2", ascending=False
)
top_ot_model_results_summary
# Out:
#       variables  anomaly    val_R2    val_r2   test_R2   test_r2  \
# 2  rcf_ndvi_tmp     True  0.649653  0.657136  0.702917  0.730501
# 1      rcf_ndvi     True  0.636982  0.645224  0.698870  0.725769
# 0           rcf     True  0.625838  0.634117  0.694785  0.720626
#
#    demean_cv_R2  demean_cv_r2  demean_test_R2  demean_test_r2
# 2           NaN           NaN             NaN             NaN
# 1           NaN           NaN             NaN             NaN
# 0           NaN           NaN             NaN             NaN

# %% [markdown]
# ### Out of Sample Predictions

# %%
oos_ot_prediction_file_pattern = str(
    here(
        "data",
        "results",
        "2_sensor_top-ot-mod_oos_predictions_10-splits_*_anom-True.csv",
    )
)
oos_ot_prediction_files = glob.glob(pathname=oos_ot_prediction_file_pattern)
sorted(oos_ot_prediction_files)
# Out:
# ['/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-ot-mod_oos_predictions_10-splits_2023-06-30_rcf_climate-False_anom-True.csv',
#  '/home/cmolitor/crop-modeling/code/4_explore_results/../../data/results/2_sensor_top-ot-mod_oos_predictions_10-splits_2023-06-30_rcf_climate-True_anom-True.csv']

# %%
oos_prediction = task_modeling_utils.merge_files(oos_prediction_files)
oos_prediction
# Out:
#       data_fold    district  year  yield_mt  log_yield  demean_log_yield  \
# 0         train       Kaoma  2019  0.523864   0.182946         -0.192782
# 1         train       Kaoma  2017  1.540420   0.404906          0.029177
# 2         train  Sinazongwe  2020  0.589120   0.201157         -0.021142
# 3         train     Kasempa  2020  3.349064   0.638396          0.077697
# 4         train   Shangombo  2020  0.741213   0.240852          0.071072
# ...         ...         ...   ...       ...        ...               ...
# 12595      test     Chadiza  2018  1.299279   0.361592         -0.142270
# 12596      test      Mkushi  2020  2.819023   0.581952         -0.022751
# 12597      test       Kitwe  2020  2.771743   0.576542          0.027490
# 12598      test   Nchelenge  2019  1.604964   0.415802         -0.090286
# 12599      test     Chavuma  2019  1.287703   0.359400         -0.156889
#
#        oos_prediction  val_fold  split  random_state variables  anomaly  \
# 0            0.279597         1      0        670487  rcf_ndvi    False
# 1            0.368818         1      0        670487  rcf_ndvi    False
# 2            0.205443         1      0        670487  rcf_ndvi    False
# 3            0.556458         1      0        670487  rcf_ndvi    False
# 4            0.167303         1      0        670487  rcf_ndvi    False
# ...               ...       ...    ...           ...       ...      ...
# 12595        0.514470         6      9        107473       rcf    False
# 12596        0.605807         6      9        107473       rcf    False
# 12597        0.562126         6      9        107473       rcf    False
# 12598        0.512967         6      9        107473       rcf    False
# 12599        0.500988         6      9        107473       rcf    False
#
#        hot_encode  demean_oos_prediction
# 0            True              -0.083021
# 1            True               0.006200
# 2            True              -0.040686
# 3            True               0.005091
# 4            True              -0.025521
# ...           ...                    ...
# 12595        True              -0.009694
# 12596        True              -0.004002
# 12597        True               0.020002
# 12598        True              -0.024283
# 12599        True              -0.042586
#
# [12600 rows x 14 columns]

# %% [markdown]
# ## Benchmark - NDVI and Climate
#
# ### Maize Yield Levels

# %%
climate = pd.read_csv(here("data", "results", "climate_model_10-splits_2023-07-05.csv"))
climate
# Out:
#      split  random_state     variables  year_start  hot_encode  anomaly  \
# 0        2         26225          ndvi        2016       False    False
# 1        1        116739           pre        2016       False     True
# 2        3        777572           pre        2016       False    False
# 3        0        670487          ndvi        2016       False     True
# 4        7        146316           pre        2016       False    False
# ..     ...           ...           ...         ...         ...      ...
# 205      9        107473  pre_tmp_ndvi        2016       False     True
# 206      9        107473  pre_tmp_ndvi        2016        True    False
# 207      8        772246  pre_tmp_ndvi        2016        True    False
# 208      5        256787  pre_tmp_ndvi        2016        True    False
# 209      6        234053  pre_tmp_ndvi        2016        True    False
#
#      total_n  train_n  test_n             best_reg_param  ...  train_r2  \
# 0        432      345      87                      [1.0]  ...  0.298571
# 1        432      345      87                      [0.1]  ...  0.170344
# 2        432      345      87                      [0.1]  ...  0.398278
# 3        432      345      87                     [0.01]  ...  0.455168
# 4        432      345      87                     [0.01]  ...  0.394274
# ..       ...      ...     ...                        ...  ...       ...
# 205      432      345      87   [1000000000.0, 0.1, 0.1]  ...  0.553652
# 206      432      345      87    [0.01, 0.01, 0.1, 0.01]  ...  0.902052
# 207      432      345      87    [0.1, 0.01, 0.01, 0.01]  ...  0.914142
# 208      432      345      87  [0.01, 0.01, 0.001, 0.01]  ...  0.914419
# 209      432      345      87    [0.1, 0.01, 0.01, 0.01]  ...  0.919001
#
#       test_R2    test_r   test_r2  demean_cv_R2  demean_cv_r  demean_cv_r2  \
# 0    0.280308  0.542938  0.294781      0.157889     0.416331      0.173331
# 1    0.102114  0.348568  0.121499           NaN          NaN           NaN
# 2    0.324432  0.575593  0.331307     -0.281685    -0.151317      0.022897
# 3    0.570649  0.756902  0.572900           NaN          NaN           NaN
# 4    0.368904  0.609873  0.371945     -0.354622    -0.085783      0.007359
# ..        ...       ...       ...           ...          ...           ...
# 205  0.632169  0.804545  0.647292           NaN          NaN           NaN
# 206  0.848890  0.921905  0.849908      0.059943     0.409038      0.167312
# 207  0.839197  0.919882  0.846182      0.213436     0.510816      0.260933
# 208  0.866718  0.931686  0.868038      0.255763     0.550629      0.303192
# 209  0.812632  0.910563  0.829124      0.260299     0.560618      0.314293
#
#      demean_test_R2  demean_test_r  demean_test_r2
# 0          0.111030       0.348220        0.121257
# 1               NaN            NaN             NaN
# 2         -0.380065      -0.219479        0.048171
# 3               NaN            NaN             NaN
# 4         -0.536602      -0.147994        0.021902
# ..              ...            ...             ...
# 205             NaN            NaN             NaN
# 206        0.565475       0.763606        0.583093
# 207        0.468034       0.686457        0.471223
# 208        0.221413       0.530530        0.281462
# 209        0.466056       0.702023        0.492836
#
# [210 rows x 26 columns]

# %%
climate_model_selection_group_cols = [
    "variables",
    "year_start",
    "hot_encode",
    "anomaly",
]

climate_results_summary = climate.groupby(
    climate_model_selection_group_cols, as_index=False
).agg(
    {
        "val_R2": "mean",
        "val_r2": "mean",
        "test_R2": "mean",
        "test_r2": "mean",
    }
)
climate_results_summary = climate_results_summary.sort_values("val_R2", ascending=False)

climate_results_summary
# Out:
#        variables  year_start  hot_encode  anomaly    val_R2    val_r2  \
# 20      tmp_ndvi        2016        True    False  0.814797  0.815993
# 14  pre_tmp_ndvi        2016        True    False  0.814602  0.815777
# 8       pre_ndvi        2016        True    False  0.791105  0.793264
# 2           ndvi        2016        True    False  0.784580  0.786098
# 11       pre_tmp        2016        True    False  0.783405  0.783853
# 17           tmp        2016        True    False  0.781280  0.782786
# 12  pre_tmp_ndvi        2016       False    False  0.708487  0.708831
# 9        pre_tmp        2016       False    False  0.686328  0.686473
# 18      tmp_ndvi        2016       False    False  0.666576  0.667014
# 5            pre        2016        True    False  0.664567  0.671982
# 15           tmp        2016       False    False  0.624383  0.624674
# 19      tmp_ndvi        2016       False     True  0.528595  0.528852
# 13  pre_tmp_ndvi        2016       False     True  0.527413  0.527773
# 6       pre_ndvi        2016       False    False  0.472942  0.474399
# 7       pre_ndvi        2016       False     True  0.459749  0.461665
# 1           ndvi        2016       False     True  0.440562  0.441639
# 10       pre_tmp        2016       False     True  0.425738  0.426256
# 16           tmp        2016       False     True  0.418427  0.418836
# 3            pre        2016       False    False  0.351658  0.352668
# 0           ndvi        2016       False    False  0.275293  0.276021
# 4            pre        2016       False     True  0.106185  0.108397
#
#      test_R2   test_r2
# 20  0.833366  0.838976
# 14  0.831254  0.837263
# 8   0.814343  0.823102
# 2   0.803736  0.813898
# 11  0.803051  0.808492
# 17  0.807925  0.814704
# 12  0.708322  0.714968
# 9   0.683861  0.689764
# 18  0.673387  0.679776
# 5   0.700099  0.717393
# 15  0.625654  0.633088
# 19  0.487933  0.507095
# 13  0.479408  0.499522
# 6   0.501810  0.517056
# 7   0.404747  0.430885
# 1   0.386680  0.412124
# 10  0.356109  0.402920
# 16  0.365434  0.412313
# 3   0.367064  0.382725
# 0   0.272649  0.293870
# 4   0.045443  0.104202

# %% [markdown]
# ### Demeaned Predictions

# %%
oos_climate_preds = pd.read_csv(
    here("data", "results", "climate_model_oos_predictions_10-splits_2023-07-05.csv")
)
oos_climate_preds
# Out:
#       data_fold  year    district  yield_mt  log_yield  demean_log_yield  \
# 0         train  2016     Luangwa  0.060554   0.025533         -0.078689
# 1         train  2016     Chilubi  2.241493   0.510745         -0.046788
# 2         train  2017  Sinazongwe  1.041549   0.309960          0.087661
# 3         train  2021   Kalulushi  3.288288   0.632284          0.045053
# 4         train  2016     Nakonde  3.007245   0.602846          0.048458
# ...         ...   ...         ...       ...        ...               ...
# 90715      test  2018       Isoka  3.400556   0.643508          0.002486
# 90716      test  2017     Serenje  2.434624   0.535879         -0.040338
# 90717      test  2016       Mongu  0.923351   0.284059          0.091288
# 90718      test  2017      Gwembe  1.904668   0.463097          0.140944
# 90719      test  2020      Katete  1.744553   0.438472          0.047361
#
#        oos_prediction  val_fold  split  random_state     variables  anomaly  \
# 0            0.447695         1      2         26225          ndvi    False
# 1            0.439148         1      2         26225          ndvi    False
# 2            0.422305         1      2         26225          ndvi    False
# 3            0.507982         1      2         26225          ndvi    False
# 4            0.462212         1      2         26225          ndvi    False
# ...               ...       ...    ...           ...           ...      ...
# 90715        0.614625         6      6        234053  pre_tmp_ndvi    False
# 90716        0.628334         6      6        234053  pre_tmp_ndvi    False
# 90717        0.194624         6      6        234053  pre_tmp_ndvi    False
# 90718        0.436605         6      6        234053  pre_tmp_ndvi    False
# 90719        0.333757         6      6        234053  pre_tmp_ndvi    False
#
#        hot_encode  year_start  demean_oos_prediction
# 0           False        2016              -0.033873
# 1           False        2016               0.011935
# 2           False        2016               0.042612
# 3           False        2016              -0.004902
# 4           False        2016              -0.000142
# ...           ...         ...                    ...
# 90715        True        2016              -0.025282
# 90716        True        2016               0.035182
# 90717        True        2016               0.026314
# 90718        True        2016               0.104396
# 90719        True        2016              -0.035669
#
# [90720 rows x 15 columns]

# %%
oos_prediction_demean_groups = [
    # "data_fold",
    "district",
    # "val_fold",
    "split",
    "random_state",
    "variables",
    "anomaly",
    "hot_encode",
    "year_start",
]
oos_prediction = task_modeling_utils.demean_by_group(
    df=oos_climate_preds,
    observed="log_yield",
    predicted="oos_prediction",
    group=oos_prediction_demean_groups,
)
oos_prediction
# Out:
#       data_fold  year    district  yield_mt  log_yield  demean_log_yield  \
# 0         train  2016     Luangwa  0.060554   0.025533         -0.078689
# 1         train  2016     Chilubi  2.241493   0.510745         -0.046788
# 2         train  2017  Sinazongwe  1.041549   0.309960          0.087661
# 3         train  2021   Kalulushi  3.288288   0.632284          0.045053
# 4         train  2016     Nakonde  3.007245   0.602846          0.048458
# ...         ...   ...         ...       ...        ...               ...
# 90715      test  2018       Isoka  3.400556   0.643508          0.002486
# 90716      test  2017     Serenje  2.434624   0.535879         -0.040338
# 90717      test  2016       Mongu  0.923351   0.284059          0.091288
# 90718      test  2017      Gwembe  1.904668   0.463097          0.140944
# 90719      test  2020      Katete  1.744553   0.438472          0.047361
#
#        oos_prediction  val_fold  split  random_state     variables  anomaly  \
# 0            0.447695         1      2         26225          ndvi    False
# 1            0.439148         1      2         26225          ndvi    False
# 2            0.422305         1      2         26225          ndvi    False
# 3            0.507982         1      2         26225          ndvi    False
# 4            0.462212         1      2         26225          ndvi    False
# ...               ...       ...    ...           ...           ...      ...
# 90715        0.614625         6      6        234053  pre_tmp_ndvi    False
# 90716        0.628334         6      6        234053  pre_tmp_ndvi    False
# 90717        0.194624         6      6        234053  pre_tmp_ndvi    False
# 90718        0.436605         6      6        234053  pre_tmp_ndvi    False
# 90719        0.333757         6      6        234053  pre_tmp_ndvi    False
#
#        hot_encode  year_start  demean_oos_prediction
# 0           False        2016              -0.033873
# 1           False        2016               0.011935
# 2           False        2016               0.042612
# 3           False        2016              -0.004902
# 4           False        2016              -0.000142
# ...           ...         ...                    ...
# 90715        True        2016              -0.025282
# 90716        True        2016               0.035182
# 90717        True        2016               0.026314
# 90718        True        2016               0.104396
# 90719        True        2016              -0.035669
#
# [90720 rows x 15 columns]

# %%
oos_prediction_r2_groups = [
    "data_fold",
    "split",
    "random_state",
    "variables",
    "anomaly",
    "hot_encode",
]

oos_prediction_R2 = oos_prediction.groupby(
    oos_prediction_r2_groups, as_index=False
).apply(get_group_R2)
oos_prediction_R2.rename(columns={None: "demean_R2"}, inplace=True)

oos_prediction_r2 = oos_prediction.groupby(
    oos_prediction_r2_groups, as_index=False
).apply(get_group_r2)
oos_prediction_r2.rename(columns={None: "demean_r"}, inplace=True)

oos_prediction_r2["demean_r2"] = oos_prediction_r2["demean_r"] ** 2

oos_prediction_summary = (
    oos_prediction_R2.set_index(oos_prediction_r2_groups)
    .join(oos_prediction_r2.set_index(oos_prediction_r2_groups))
    .reset_index()
)

oos_prediction_summary.sort_values(["variables", "data_fold"])
# Out:
#     data_fold  split  random_state variables  anomaly  hot_encode  demean_R2  \
# 0        test      0        670487      ndvi    False       False   0.240765
# 1        test      0        670487      ndvi    False        True   0.519794
# 2        test      0        670487      ndvi     True       False   0.562309
# 21       test      1        116739      ndvi    False       False   0.185826
# 22       test      1        116739      ndvi    False        True   0.383004
# ..        ...    ...           ...       ...      ...         ...        ...
# 397     train      8        772246  tmp_ndvi    False        True   0.235446
# 398     train      8        772246  tmp_ndvi     True       False   0.533611
# 417     train      9        107473  tmp_ndvi    False       False   0.262945
# 418     train      9        107473  tmp_ndvi    False        True   0.103748
# 419     train      9        107473  tmp_ndvi     True       False   0.493898
#
#      demean_r  demean_r2
# 0    0.581621   0.338284
# 1    0.727101   0.528676
# 2    0.751157   0.564237
# 21   0.461670   0.213139
# 22   0.619172   0.383374
# ..        ...        ...
# 397  0.524526   0.275127
# 398  0.730545   0.533696
# 417  0.520624   0.271049
# 418  0.421087   0.177314
# 419  0.702951   0.494140
#
# [420 rows x 9 columns]

# %%
oos_prediction_summary_r2_groups = [
    "data_fold",
    "anomaly",
    "hot_encode",
    "variables",
]
oos_prediction_summary = (
    oos_prediction_summary.groupby(oos_prediction_summary_r2_groups, as_index=False)
    .agg(
        {
            "demean_R2": "mean",
            "demean_r2": "mean",
            # "demean_R2": "sem",
            # "demean_r2": "sem",
        }
    )
    .sort_values("variables")
)
# oos_prediction_summary  # .sort_values(["variables", "data_fold"])

# %%
# Pivot the DataFrame
oos_prediction_summary = oos_prediction_summary.pivot_table(
    index=[
        "anomaly",
        "hot_encode",
        "variables",
    ],
    columns="data_fold",
)

# Flatten the MultiIndex columns
oos_prediction_summary.columns = [
    "_".join(col) for col in oos_prediction_summary.columns
]

# Reset the index
oos_prediction_summary = oos_prediction_summary.reset_index()
oos_prediction_summary = oos_prediction_summary.set_index(
    [
        "variables",
        "anomaly",
        "hot_encode",
        "demean_R2_train",
        "demean_r2_train",
        "demean_R2_test",
        "demean_r2_test",
    ]
)
oos_prediction_summary = oos_prediction_summary.reset_index()
oos_prediction_summary.sort_values("demean_R2_train", ascending=False)
# Out:
#        variables  anomaly  hot_encode  demean_R2_train  demean_r2_train  \
# 20      tmp_ndvi     True       False         0.530848         0.531399
# 18  pre_tmp_ndvi     True       False         0.529823         0.530509
# 16      pre_ndvi     True       False         0.462839         0.464957
# 14          ndvi     True       False         0.442356         0.443799
# 17       pre_tmp     True       False         0.427708         0.428512
# 19           tmp     True       False         0.419594         0.420349
# 6       tmp_ndvi    False       False         0.345402         0.358642
# 4   pre_tmp_ndvi    False       False         0.312575         0.349396
# 5            tmp    False       False         0.292189         0.300871
# 3        pre_tmp    False       False         0.278274         0.311435
# 11  pre_tmp_ndvi    False        True         0.192646         0.255906
# 13      tmp_ndvi    False        True         0.191583         0.253474
# 0           ndvi    False       False         0.183846         0.189010
# 15           pre     True       False         0.107759         0.110545
# 9       pre_ndvi    False        True         0.097641         0.186494
# 2       pre_ndvi    False       False         0.086367         0.152075
# 7           ndvi    False        True         0.069832         0.155312
# 10       pre_tmp    False        True         0.058785         0.155125
# 12           tmp    False        True         0.046382         0.150789
# 1            pre    False       False        -0.317289         0.018317
# 8            pre    False        True        -0.471870         0.051367
#
#     demean_R2_test  demean_r2_test
# 20        0.485076        0.500791
# 18        0.476054        0.492671
# 16        0.400379        0.422695
# 14        0.386170        0.406944
# 17        0.353780        0.397824
# 19        0.365583        0.409010
# 6         0.303817        0.351196
# 4         0.251190        0.328011
# 5         0.247677        0.305017
# 3         0.239848        0.312614
# 11        0.411838        0.434075
# 13        0.413384        0.437167
# 0         0.124014        0.176022
# 15        0.047786        0.099068
# 9         0.360786        0.383572
# 2         0.005798        0.150130
# 7         0.330809        0.354433
# 10        0.293347        0.337877
# 12        0.313956        0.356027
# 1        -0.331442        0.020448
# 8         0.006051        0.079982

# %%
oos_prediction_summary.loc[
    (oos_prediction_summary["anomaly"] == False)
    & (oos_prediction_summary["hot_encode"] == True)
].sort_values("demean_R2_train", ascending=False)
# Out:
#        variables  anomaly  hot_encode  demean_R2_train  demean_r2_train  \
# 11  pre_tmp_ndvi    False        True         0.192646         0.255906
# 13      tmp_ndvi    False        True         0.191583         0.253474
# 9       pre_ndvi    False        True         0.097641         0.186494
# 7           ndvi    False        True         0.069832         0.155312
# 10       pre_tmp    False        True         0.058785         0.155125
# 12           tmp    False        True         0.046382         0.150789
# 8            pre    False        True        -0.471870         0.051367
#
#     demean_R2_test  demean_r2_test
# 11        0.411838        0.434075
# 13        0.413384        0.437167
# 9         0.360786        0.383572
# 7         0.330809        0.354433
# 10        0.293347        0.337877
# 12        0.313956        0.356027
# 8         0.006051        0.079982
